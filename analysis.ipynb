# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data import

# %%
df = pd.read_csv('Data_Benzene_Reduced.csv', sep=";", header=None)

# %%
df.shape
# Out:
# (36, 50)

# %%
df.head()
# Out:
#     0     1            2            3            4            5            6   \
# 0  0.0  0.80  1626.823165  1457.396340  1326.435723  1194.024158  1020.130396
# 1  0.0  0.91  1617.220124  1496.416724  1358.930793  1232.823997  1023.166629
# 2  0.0  1.10  1605.739019  1476.724533  1368.610846  1252.351488   983.631501
# 3  0.0  1.20  1550.283200  1437.776717  1334.169804  1211.333967   980.769563
# 4  0.0  1.05  1616.214267  1498.777159  1374.389533  1262.140625  1020.856509
#
#            7           8           9   ...           40           41  \
# 0  976.520203  973.181964  972.806042  ...   994.393705   988.421801
# 1  994.097236  991.023965  990.423767  ...  1012.880831  1011.253642
# 2  934.692010  928.948156  927.367393  ...   947.836999   939.282976
# 3  890.930800  889.029933  883.938276  ...   903.923849   898.114012
# 4  972.089437  968.996714  968.696792  ...   978.957244   977.001619
#
#             42           43           44           45           46  \
# 0  1278.077833  1242.645205  1215.819200  1196.278582  1140.592824
# 1  1319.520653  1283.193326  1258.192950  1227.537987  1159.581762
# 2  1263.729556  1237.507083  1212.880395  1179.206467  1128.985843
# 3  1198.395400  1175.865189  1147.062739  1129.481143  1069.843556
# 4  1299.825556  1271.606776  1251.744990  1220.667188  1150.809542
#
#             47           48           49
# 0  1077.747033  1007.577774   992.954233
# 1  1098.871710  1023.649522  1015.448677
# 2  1056.023440   968.464531   943.440883
# 3  1014.703550   927.781498   903.919877
# 4  1078.017038   994.420744   981.882100
#
# [5 rows x 50 columns]

# %%
df.rename(columns={0: 'benzene', 1: 'eq_ratio'}, inplace=True)

# %%
df.head()
# Out:
#    benzene  eq_ratio            2            3            4            5  \
# 0      0.0      0.80  1626.823165  1457.396340  1326.435723  1194.024158
# 1      0.0      0.91  1617.220124  1496.416724  1358.930793  1232.823997
# 2      0.0      1.10  1605.739019  1476.724533  1368.610846  1252.351488
# 3      0.0      1.20  1550.283200  1437.776717  1334.169804  1211.333967
# 4      0.0      1.05  1616.214267  1498.777159  1374.389533  1262.140625
#
#              6           7           8           9  ...           40  \
# 0  1020.130396  976.520203  973.181964  972.806042  ...   994.393705
# 1  1023.166629  994.097236  991.023965  990.423767  ...  1012.880831
# 2   983.631501  934.692010  928.948156  927.367393  ...   947.836999
# 3   980.769563  890.930800  889.029933  883.938276  ...   903.923849
# 4  1020.856509  972.089437  968.996714  968.696792  ...   978.957244
#
#             41           42           43           44           45  \
# 0   988.421801  1278.077833  1242.645205  1215.819200  1196.278582
# 1  1011.253642  1319.520653  1283.193326  1258.192950  1227.537987
# 2   939.282976  1263.729556  1237.507083  1212.880395  1179.206467
# 3   898.114012  1198.395400  1175.865189  1147.062739  1129.481143
# 4   977.001619  1299.825556  1271.606776  1251.744990  1220.667188
#
#             46           47           48           49
# 0  1140.592824  1077.747033  1007.577774   992.954233
# 1  1159.581762  1098.871710  1023.649522  1015.448677
# 2  1128.985843  1056.023440   968.464531   943.440883
# 3  1069.843556  1014.703550   927.781498   903.919877
# 4  1150.809542  1078.017038   994.420744   981.882100
#
# [5 rows x 50 columns]

# %% [markdown]
# # Task 1

# %% [markdown]
# ## Benzene

# %%
df_by_benzene = df.groupby('benzene', as_index=False).mean()

# %%
df_by_benzene
# Out:
#    benzene  eq_ratio            2            3            4            5  \
# 0     0.00      1.01  1610.222623  1480.821713  1361.219602  1235.925210
# 1     0.50      1.01  1597.026174  1464.022448  1342.987226  1222.114181
# 2     1.12      1.01  1604.587672  1470.227080  1349.308393  1238.550394
# 3     2.00      1.01  1602.183216  1465.652736  1350.677390  1231.300240
# 4     3.00      1.01  1598.845449  1453.642618  1346.772733  1220.625551
# 5     5.00      1.01  1582.595592  1458.685382  1340.434300  1212.105156
#
#              6           7           8           9  ...          40  \
# 0  1010.173148  959.811883  956.577235  954.947609  ...  975.116527
# 1  1004.820473  956.311859  952.493194  951.374962  ...  969.362537
# 2  1015.803857  963.590353  960.265217  958.310991  ...  977.961898
# 3  1015.838982  962.204087  958.442813  956.036501  ...  999.272234
# 4  1009.959144  963.338822  960.011470  958.258044  ...  993.517742
# 5  1007.465005  965.292296  962.143794  960.597849  ...  995.122347
#
#            41           42           43           44           45  \
# 0  969.656825  1285.413627  1252.374269  1227.845423  1200.299428
# 1  962.946901  1277.925570  1244.931059  1222.826026  1192.379240
# 2  969.678177  1281.322024  1250.755510  1225.294789  1195.129795
# 3  977.733116  1157.958361  1141.662840  1132.257349  1122.587604
# 4  972.018083  1151.233098  1132.822079  1123.938826  1112.440360
# 5  975.020607  1147.282632  1124.448339  1118.821101  1108.674451
#
#             46           47           48          49
# 0  1137.727570  1071.696977   991.055645  974.217695
# 1  1127.890680  1060.669343   984.634799  967.414720
# 2  1128.498491  1068.835784   992.540007  972.586670
# 3  1097.605050  1070.634967  1029.859598  994.417936
# 4  1086.809793  1061.173149  1021.723277  995.511286
# 5  1086.113291  1060.055767  1025.086557  993.792337
#
# [6 rows x 50 columns]

# %%
grid_shape = (6, 8)

# %% [markdown]
# ### Heatmaps

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(30, 30), sharey=True)
fig.set_facecolor('white')
# find min and max values to get the same scale
min_val = df_by_benzene.iloc[:,2:].min().min()
max_val = df_by_benzene.iloc[:,2:].max().max()
for index, value in enumerate(df_by_benzene["benzene"]):
    T_data = np.flip(df_by_benzene[df_by_benzene["benzene"] == value].iloc[:,2:].to_numpy().reshape(grid_shape), axis=0)
    sns.heatmap(T_data, cmap="YlOrBr", ax=ax.flatten()[index], vmin=min_val, vmax=max_val, annot=True, fmt=".2f")
    ax.flatten()[index].set_title(f"Grid temperatures for {value} benzene percentage")

# %% [markdown]
# ### Histograms

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 20), sharey=True)
fig.set_facecolor('white')

for index, benzene_p in enumerate(df["benzene"].unique()):
    # array of temperatures for each benzene percentage
    T_data = np.flip(df[df["benzene"] == benzene_p].iloc[:,2:].to_numpy().flatten(), axis=0)
    # plot the histogram
    sns.histplot(T_data, ax=ax.flatten()[index], kde=False, bins=50)
    ax.flatten()[index].set_title(f"Temperature distribution for {benzene_p} benzene percentage")

# %% [markdown]
# ### Box plots

# %%
fig = plt.figure(figsize=(12,8))
# put all temperatures in a single column
benzene_boxplot_df = df.melt(id_vars=("benzene", "eq_ratio"), var_name="grid_position", value_name="temperature")
sns.boxplot(x="benzene", y="temperature", data=benzene_boxplot_df)
plt.xlabel("Benzene percentage")
plt.ylabel("Temperature")
plt.title("Boxplot of temperature for benzene percentage")
# Out:
# Text(0.5, 1.0, 'Boxplot of temperature for benzene percentage')

# %% [markdown]
# ## Equivalence ratio

# %%
df["eq_ratio"].nunique()
# Out:
# 6

# %%
df_by_ratio = df.groupby('eq_ratio', as_index=False).mean()

# %%
df_by_ratio
# Out:
#    eq_ratio   benzene            2            3            4            5  \
# 0      0.80  1.936667  1635.551670  1460.972992  1326.089779  1198.778002
# 1      0.91  1.936667  1631.447501  1517.508132  1380.570888  1249.448799
# 2      1.00  1.936667  1632.705303  1484.939243  1383.318624  1255.253331
# 3      1.05  1.936667  1617.613808  1486.262772  1366.195710  1246.288093
# 4      1.10  1.936667  1580.726010  1459.156428  1348.430558  1238.086790
# 5      1.20  1.936667  1497.416433  1384.212409  1286.794085  1172.765717
#
#              6           7           8           9  ...           40  \
# 0  1014.939981  977.605825  974.581820  973.701155  ...  1006.079266
# 1  1046.097333  990.473283  986.875663  986.116614  ...  1023.671444
# 2  1028.511111  994.986406  992.560487  991.231643  ...  1007.901363
# 3  1022.284433  971.344854  968.295870  968.068427  ...   991.363380
# 4   990.244613  941.444601  937.138932  934.427715  ...   968.776142
# 5   961.983140  894.694330  890.480951  885.980402  ...   912.561689
#
#             41           42           43           44           45  \
# 0   989.306769  1218.493413  1192.686419  1182.655340  1165.892789
# 1  1007.629428  1243.859716  1224.438506  1209.928361  1189.864533
# 2   999.867931  1340.662530  1291.343613  1266.270820  1237.671650
# 3   981.521166  1223.631260  1201.349480  1186.180730  1165.604972
# 4   949.172988  1181.775374  1163.881109  1147.662130  1127.671255
# 5   899.555427  1092.713019  1073.294969  1058.286132  1044.805680
#
#             46           47           48           49
# 0  1123.781338  1087.764661  1044.700228  1015.325688
# 1  1145.552146  1102.011655  1045.649230  1018.867855
# 2  1175.835838  1107.159793  1026.160882  1005.195226
# 3  1121.370054  1076.121528  1015.211621   991.531699
# 4  1088.599732  1045.335225   984.857695   958.510019
# 5  1009.505767   974.673125   928.320226   908.510157
#
# [6 rows x 50 columns]

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(30, 30), sharey=True)
fig.set_facecolor('white')
# find min and max values to get the same scale
min_val = df_by_ratio.iloc[:,2:].min().min()
max_val = df_by_ratio.iloc[:,2:].max().max()
for index, value in enumerate(df_by_ratio["eq_ratio"]):
    T_data = np.flip(df_by_ratio[df_by_ratio["eq_ratio"] == value].iloc[:,2:].to_numpy().reshape(grid_shape), axis=0)
    sns.heatmap(T_data, cmap="YlOrBr", ax=ax.flatten()[index], vmin=min_val, vmax=max_val, annot=True, fmt=".2f")
    ax.flatten()[index].set_title(f"Grid temperatures for {value} equivalence ratio")
